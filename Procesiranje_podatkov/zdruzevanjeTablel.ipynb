# %% [markdown]
# <a href="https://colab.research.google.com/github/Tara2712/Informatika/blob/main/zdruzevanjeTablel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
sr = pd.read_excel("cleaned_file_2-2.xlsx", index_col="SR")

sr_podrobno = pd.read_excel("cleaned_file.xlsx")

# %%
sr.head()
# Out:
#                                                NAZIV_SR  \
# SR
# SR271424                                       3-344158
# SR271425                                       3-137428
# SR271426             Kadri - prva posodobitev ob vstopu
# SR271427  Enotna vloga, Projektni pogoji, SkP, SzP, PoP
# SR271428          Izostala arhiviranja preteklega tedna
#
#                    DATUM_NASTANKA_SR  STATUS
# SR
# SR271424  2024-01-03 06:40:03.759000  CLOSED
# SR271425  2024-01-03 07:00:02.971000  CLOSED
# SR271426  2024-01-03 07:25:14.172000  CLOSED
# SR271427  2024-01-03 07:29:10.194000  CLOSED
# SR271428  2024-01-03 07:30:02.831000  CLOSED

# %%
sr_podrobno.head()
# Out:
#   RECORDKEY  WORKLOGID                              OPIS  \
# 0  SR272332     468138                           8090161
# 1  SR271673     468066                 Potrjujem rešitev
# 2  SR274081     472037                                MX
# 3  SR281496     482708                           Rešitev
# 4  SR274181     470972  Odgovor glede EM9210 - 29.2.2024
#
#                                         DOLGI_OPIS_X  DOLZINA
# 0                                        NE GRE!!! !     27.0
# 1                                                NaN      NaN
# 2  Kar se tiče MX, lahko to izvedemo na več način...    311.0
# 3  Kot pojasjneno preko maila je ostala samo še n...    513.0
# 4  Slika, kjer se vidi, da ima EM9210 OE = 6182 j...    853.0

# %%
sr_podrobno.rename(columns={'RECORDKEY': 'SR'}, inplace=True)

# %%
sr_podrobno.head()
# Out:
#          SR  WORKLOGID                              OPIS  \
# 0  SR272332     468138                           8090161
# 1  SR271673     468066                 Potrjujem rešitev
# 2  SR274081     472037                                MX
# 3  SR281496     482708                           Rešitev
# 4  SR274181     470972  Odgovor glede EM9210 - 29.2.2024
#
#                                         DOLGI_OPIS_X  DOLZINA
# 0                                        NE GRE!!! !     27.0
# 1                                                NaN      NaN
# 2  Kar se tiče MX, lahko to izvedemo na več način...    311.0
# 3  Kot pojasjneno preko maila je ostala samo še n...    513.0
# 4  Slika, kjer se vidi, da ima EM9210 OE = 6182 j...    853.0

# %%
sr_podrobno.set_index('SR', inplace=True)

# %%
sr_podrobno.head()
# Out:
#           WORKLOGID                              OPIS  \
# SR
# SR272332     468138                           8090161
# SR271673     468066                 Potrjujem rešitev
# SR274081     472037                                MX
# SR281496     482708                           Rešitev
# SR274181     470972  Odgovor glede EM9210 - 29.2.2024
#
#                                                DOLGI_OPIS_X  DOLZINA
# SR
# SR272332                                        NE GRE!!! !     27.0
# SR271673                                                NaN      NaN
# SR274081  Kar se tiče MX, lahko to izvedemo na več način...    311.0
# SR281496  Kot pojasjneno preko maila je ostala samo še n...    513.0
# SR274181  Slika, kjer se vidi, da ima EM9210 OE = 6182 j...    853.0

# %%
sr.isna().sum()
# Out:
# NAZIV_SR             0
# DATUM_NASTANKA_SR    0
# STATUS               0
# dtype: int64

# %%
sr_podrobno.isna().sum()
# Out:
# WORKLOGID          0
# OPIS            1656
# DOLGI_OPIS_X    3956
# DOLZINA         3956
# dtype: int64

# %%
zdruzen_df = pd.merge(sr, sr_podrobno, on='SR', how='left')

# %%
zdruzen_df.head()
# Out:
#                                     NAZIV_SR           DATUM_NASTANKA_SR  \
# SR
# SR271424                            3-344158  2024-01-03 06:40:03.759000
# SR271425                            3-137428  2024-01-03 07:00:02.971000
# SR271425                            3-137428  2024-01-03 07:00:02.971000
# SR271426  Kadri - prva posodobitev ob vstopu  2024-01-03 07:25:14.172000
# SR271426  Kadri - prva posodobitev ob vstopu  2024-01-03 07:25:14.172000
#
#           STATUS  WORKLOGID                              OPIS  \
# SR
# SR271424  CLOSED   466836.0                           Rešitev
# SR271425  CLOSED   466837.0                           Rešitev
# SR271425  CLOSED   466899.0                 Potrjujem rešitev
# SR271426  CLOSED   466840.0  Sporočilo Informatika - 3.1.2024
# SR271426  CLOSED   467059.0                           Rešitev
#
#                                                DOLGI_OPIS_X  DOLZINA
# SR
# SR271424                       zahteva na oddano LP Goran !     85.0
# SR271425  stornirajte spremembo in pričnite ponovno s pr...    135.0
# SR271425                                                NaN      NaN
# SR271426  Zdravo - pogledala sem nastavitve ure v PROD i...    337.0
# SR271426  Časovne nastavitve smo popravili. Danes ni bil...    126.0

# %%
zdruzen_df.to_csv("zdruzen_df.csv")

# %%
zdruzen_df.drop(columns="DOLZINA", inplace=True)

# %%
zdruzen_df.to_csv("zdruzen_df_brez_dolzine.csv")

# %%
zdruzen_df.isna().sum()
# Out:
# NAZIV_SR                0
# DATUM_NASTANKA_SR       0
# STATUS                  0
# WORKLOGID             900
# OPIS                 2499
# DOLGI_OPIS_X         4781
# dtype: int64

# %%
zdruzen_df.columns
# Out:
# Index(['NAZIV_SR', 'DATUM_NASTANKA_SR', 'STATUS', 'WORKLOGID', 'OPIS',
#        'DOLGI_OPIS_X'],
#       dtype='object')
