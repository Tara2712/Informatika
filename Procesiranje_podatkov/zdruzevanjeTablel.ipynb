# %% [markdown]
# <a href="https://colab.research.google.com/github/Tara2712/Informatika/blob/main/Procesiranje_podatkov/zdruzevanjeTablel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
sr = pd.read_excel("cleaned_file_2-2.xlsx", index_col="SR")
sr_podrobno = pd.read_excel("cleaned_file.xlsx")

# %%
# sr.head()

# %%
# sr_podrobno.head()

# %%
sr.describe()
# Out:
#         NAZIV_SR    DATUM_NASTANKA_SR  STATUS
# count      18423                18423   18423
# unique     13415                18417      11
# top     IT - eIS  2025-02-17 08:10:23  CLOSED
# freq        1024                    2   17872

# %%
sr_podrobno.describe()
# Out:
#            WORKLOGID       DOLZINA
# count   28098.000000  2.414200e+04
# mean   481482.008292  1.825348e+03
# std      8440.756293  1.938071e+04
# min    466830.000000  2.100000e+01
# 25%    474192.250000  1.000000e+02
# 50%    481459.500000  1.500000e+02
# 75%    488791.750000  2.300000e+02
# max    496072.000000  1.110319e+06

# %% [markdown]
# Sprememba imena stolpca v SR, da se lahko merga pol

# %%
sr_podrobno.rename(columns={'RECORDKEY': 'SR'}, inplace=True)

# %%
# sr_podrobno.head()

# %%
sr_podrobno.set_index('SR', inplace=True)

# %%
zdruzen_df = pd.merge(sr, sr_podrobno, on='SR', how='left')

# %%
zdruzen_df.head()
# Out:
#                                     NAZIV_SR           DATUM_NASTANKA_SR  \
# SR
# SR271424                            3-344158  2024-01-03 06:40:03.759000
# SR271425                            3-137428  2024-01-03 07:00:02.971000
# SR271425                            3-137428  2024-01-03 07:00:02.971000
# SR271426  Kadri - prva posodobitev ob vstopu  2024-01-03 07:25:14.172000
# SR271426  Kadri - prva posodobitev ob vstopu  2024-01-03 07:25:14.172000
#
#           STATUS  WORKLOGID                              OPIS  \
# SR
# SR271424  CLOSED   466836.0                           Rešitev
# SR271425  CLOSED   466837.0                           Rešitev
# SR271425  CLOSED   466899.0                 Potrjujem rešitev
# SR271426  CLOSED   466840.0  Sporočilo Informatika - 3.1.2024
# SR271426  CLOSED   467059.0                           Rešitev
#
#                                                DOLGI_OPIS_X  DOLZINA
# SR
# ...

# %%
zdruzen_df.count()
# Out:
# NAZIV_SR             28353
# DATUM_NASTANKA_SR    28353
# STATUS               28353
# WORKLOGID            27453
# OPIS                 25854
# DOLGI_OPIS_X         23572
# DOLZINA              23572
# dtype: int64

# %%
# sr_podrobno.head()

# %%
sr.isna().sum()
# Out:
# NAZIV_SR             0
# DATUM_NASTANKA_SR    0
# STATUS               0
# dtype: int64

# %%
sr_podrobno.isna().sum()
# Out:
# WORKLOGID          0
# OPIS            1656
# DOLGI_OPIS_X    3956
# DOLZINA         3956
# dtype: int64

# %%
zdruzen_df.describe()
# Out:
#            WORKLOGID       DOLZINA
# count   27453.000000  2.357200e+04
# mean   481709.051579  1.850242e+03
# std      8370.787606  1.960706e+04
# min    466835.000000  2.100000e+01
# 25%    474553.000000  1.000000e+02
# 50%    481759.000000  1.500000e+02
# 75%    488950.000000  2.260000e+02
# max    496072.000000  1.110319e+06

# %%
# zdruzen_df.head()

# %%
zdruzen_df.to_csv("zdruzen_df.csv")

# %%
zdruzen_df.drop(columns="DOLZINA", inplace=True)

# %%
zdruzen_df.to_csv("zdruzen_df_brez_dolzine.csv")

# %%
zdruzen_df.isna().sum()
# Out:
# NAZIV_SR                0
# DATUM_NASTANKA_SR       0
# STATUS                  0
# WORKLOGID             900
# OPIS                 2499
# DOLGI_OPIS_X         4781
# dtype: int64

# %%
zdruzen_df.columns
# Out:
# Index(['NAZIV_SR', 'DATUM_NASTANKA_SR', 'STATUS', 'WORKLOGID', 'OPIS',
#        'DOLGI_OPIS_X'],
#       dtype='object')

# %%
# zdruzen_df.head(5)

# %%
zdruzen_df.isna().sum()
# Out:
# NAZIV_SR                0
# DATUM_NASTANKA_SR       0
# STATUS                  0
# WORKLOGID             900
# OPIS                 2499
# DOLGI_OPIS_X         4781
# dtype: int64

# %%
stolpci_za_preverit = ["OPIS", "DOLGI_OPIS_X"]

num_both_null = zdruzen_df[(zdruzen_df['OPIS'].isna()) & (zdruzen_df['DOLGI_OPIS_X'].isna())].shape[0] #& (zdruzen_df['WORKLOGID'].isna())
print(f"Number of rows where both 'OPIS' and 'DOLGI_OPIS_X' are null: {num_both_null}")
# Out:
# Number of rows where both 'OPIS' and 'DOLGI_OPIS_X' are null: 1286

# %%
df_pociscen = zdruzen_df.dropna(subset=stolpci_za_preverit, how="all")

# %%
df_pociscen.isna().sum()
# Out:
# NAZIV_SR                0
# DATUM_NASTANKA_SR       0
# STATUS                  0
# WORKLOGID               0
# OPIS                 1213
# DOLGI_OPIS_X         3495
# dtype: int64

# %%
# df_pociscen.head(10)

# %%
df_pociscen.to_csv("df_pociscen.csv")
